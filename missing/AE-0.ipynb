# %%
import tensorflow as tf
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.12.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
X_val = np.load('gdrive/My Drive/UPJV/missing/X_val.npy')
y_val = np.load('gdrive/My Drive/UPJV/missing/y_val.npy')
X_test = np.load('gdrive/My Drive/UPJV/missing/X_test.npy')
y_test = np.load('gdrive/My Drive/UPJV/missing/y_test.npy')

# %%
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (15921, 303)
# (15921, 303)
# (15920, 303)
# (15920, 303)

# %%
noisy_point_clouds = np.concatenate((X_val, X_test), axis=0)
noisy_point_clouds = noisy_point_clouds.reshape(-1, 101, 3)
noisy_point_clouds.shape
# Out:
# (31841, 101, 3)

# %%
clean_point_clouds = np.concatenate((y_val, y_test), axis=0)
clean_point_clouds = clean_point_clouds.reshape(-1, 101, 3)
clean_point_clouds.shape
# Out:
# (31841, 101, 3)

# %%
from sklearn.model_selection import train_test_split

# Assuming your original dataset is noisy_point_clouds and clean_point_clouds

noisy_train, noisy_test, clean_train, clean_test = train_test_split(noisy_point_clouds, clean_point_clouds, test_size=0.2, random_state=42)

# Now, noisy_train and clean_train are your training dataset.
# And, noisy_test and clean_test are your test dataset.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape

# Assuming each point cloud has num_points points and each point has 3 dimensions
num_points = 101
dims = 3
encoding_dim = 32  # feel free to change this value depending on your needs

# This is the size of our encoded representations
input_point_cloud = Input(shape=(num_points, dims))

# Flatten the input
x = Flatten()(input_point_cloud)
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(x)

# "decoded" is the lossy reconstruction of the input
decoded = Dense(num_points*dims, activation='sigmoid')(encoded)

# Reshape to original shape
decoded = Reshape((num_points, dims))(decoded)

# This model maps an input to its reconstruction
autoencoder = Model(input_point_cloud, decoded)

# Separate encoder model
# This model maps an input to its encoded representation
encoder = Model(input_point_cloud, encoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Assume noisy_point_clouds_flattened and clean_point_clouds_flattened are your flat input and target data
history = autoencoder.fit(noisy_point_clouds, clean_point_clouds,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_split=0.2)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 6s 5ms/step - loss: 0.0276 - val_loss: 0.0046
# Epoch 2/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 3/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 4/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 5/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 6/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 7/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 8/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 9/100
# 100/100 [==============================] - 1s 6ms/step - loss: 9.5021e-04 - val_loss: 8.9834e-04
# Epoch 10/100
# 100/100 [==============================] - 1s 6ms/step - loss: 8.5267e-04 - val_loss: 8.1759e-04
# Epoch 11/100
# 100/100 [==============================] - 1s 8ms/step - loss: 7.8057e-04 - val_loss: 7.5176e-04
# Epoch 12/100
# 100/100 [==============================] - 1s 8ms/step - loss: 7.1636e-04 - val_loss: 6.8885e-04
# Epoch 13/100
# 100/100 [==============================] - 1s 9ms/step - loss: 6.5797e-04 - val_loss: 6.3345e-04
# Epoch 14/100
# 100/100 [==============================] - 1s 7ms/step - loss: 6.0855e-04 - val_loss: 5.9074e-04
# Epoch 15/100
# 100/100 [==============================] - 0s 5ms/step - loss: 5.6732e-04 - val_loss: 5.5174e-04
# Epoch 16/100
# 100/100 [==============================] - 0s 4ms/step - loss: 5.3453e-04 - val_loss: 5.2317e-04
# Epoch 17/100
# 100/100 [==============================] - 0s 4ms/step - loss: 5.0873e-04 - val_loss: 5.0107e-04
# Epoch 18/100
# 100/100 [==============================] - 0s 4ms/step - loss: 4.8625e-04 - val_loss: 4.7919e-04
# Epoch 19/100
# 100/100 [==============================] - 0s 4ms/step - loss: 4.6739e-04 - val_loss: 4.6560e-04
# Epoch 20/100
# 100/100 [==============================] - 0s 4ms/step - loss: 4.5160e-04 - val_loss: 4.4594e-04
# Epoch 21/100
# 100/100 [==============================] - 0s 4ms/step - loss: 4.3740e-04 - val_loss: 4.3571e-04
# Epoch 22/100
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2512e-04 - val_loss: 4.2048e-04
# Epoch 23/100
# 100/100 [==============================] - 0s 4ms/step - loss: 4.1403e-04 - val_loss: 4.1221e-04
# Epoch 24/100
# 100/100 [==============================] - 0s 4ms/step - loss: 4.0424e-04 - val_loss: 4.0045e-04
# Epoch 25/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.9516e-04 - val_loss: 3.9509e-04
# Epoch 26/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.8706e-04 - val_loss: 3.8488e-04
# Epoch 27/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.8083e-04 - val_loss: 3.8004e-04
# Epoch 28/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.7263e-04 - val_loss: 3.7050e-04
# Epoch 29/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.6555e-04 - val_loss: 3.6334e-04
# Epoch 30/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.5848e-04 - val_loss: 3.5911e-04
# Epoch 31/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.5313e-04 - val_loss: 3.5408e-04
# Epoch 32/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.4762e-04 - val_loss: 3.4748e-04
# Epoch 33/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.4222e-04 - val_loss: 3.4055e-04
# Epoch 34/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.3739e-04 - val_loss: 3.3865e-04
# Epoch 35/100
# 100/100 [==============================] - 0s 5ms/step - loss: 3.3260e-04 - val_loss: 3.3144e-04
# Epoch 36/100
# 100/100 [==============================] - 1s 6ms/step - loss: 3.2787e-04 - val_loss: 3.2705e-04
# Epoch 37/100
# 100/100 [==============================] - 1s 5ms/step - loss: 3.2382e-04 - val_loss: 3.2157e-04
# Epoch 38/100
# 100/100 [==============================] - 1s 5ms/step - loss: 3.1886e-04 - val_loss: 3.1801e-04
# Epoch 39/100
# 100/100 [==============================] - 1s 5ms/step - loss: 3.1444e-04 - val_loss: 3.1717e-04
# Epoch 40/100
# 100/100 [==============================] - 1s 6ms/step - loss: 3.1086e-04 - val_loss: 3.1220e-04
# Epoch 41/100
# 100/100 [==============================] - 1s 6ms/step - loss: 3.0714e-04 - val_loss: 3.0904e-04
# Epoch 42/100
# 100/100 [==============================] - 0s 4ms/step - loss: 3.0405e-04 - val_loss: 3.0257e-04
# Epoch 43/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.9959e-04 - val_loss: 2.9891e-04
# Epoch 44/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.9578e-04 - val_loss: 2.9773e-04
# Epoch 45/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.9206e-04 - val_loss: 2.9023e-04
# Epoch 46/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.8822e-04 - val_loss: 2.8751e-04
# Epoch 47/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.8485e-04 - val_loss: 2.8443e-04
# Epoch 48/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.8127e-04 - val_loss: 2.8228e-04
# Epoch 49/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.7845e-04 - val_loss: 2.7879e-04
# Epoch 50/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.7662e-04 - val_loss: 2.7727e-04
# Epoch 51/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.7286e-04 - val_loss: 2.7132e-04
# Epoch 52/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.7018e-04 - val_loss: 2.7010e-04
# Epoch 53/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.6836e-04 - val_loss: 2.7051e-04
# Epoch 54/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.6673e-04 - val_loss: 2.6426e-04
# Epoch 55/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.6434e-04 - val_loss: 2.6428e-04
# Epoch 56/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.6215e-04 - val_loss: 2.6384e-04
# Epoch 57/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.6045e-04 - val_loss: 2.6089e-04
# Epoch 58/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.5908e-04 - val_loss: 2.6258e-04
# Epoch 59/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.5845e-04 - val_loss: 2.5985e-04
# Epoch 60/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.5706e-04 - val_loss: 2.5611e-04
# Epoch 61/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.5502e-04 - val_loss: 2.5411e-04
# Epoch 62/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.5373e-04 - val_loss: 2.5406e-04
# Epoch 63/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.5325e-04 - val_loss: 2.5384e-04
# Epoch 64/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.5179e-04 - val_loss: 2.5282e-04
# Epoch 65/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.5060e-04 - val_loss: 2.5057e-04
# Epoch 66/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.4970e-04 - val_loss: 2.5033e-04
# Epoch 67/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.4992e-04 - val_loss: 2.5048e-04
# Epoch 68/100
# 100/100 [==============================] - 1s 5ms/step - loss: 2.4779e-04 - val_loss: 2.4814e-04
# Epoch 69/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.4762e-04 - val_loss: 2.4943e-04
# Epoch 70/100
# 100/100 [==============================] - 1s 5ms/step - loss: 2.4775e-04 - val_loss: 2.5183e-04
# Epoch 71/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.4701e-04 - val_loss: 2.4657e-04
# Epoch 72/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.4617e-04 - val_loss: 2.4814e-04
# Epoch 73/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.4612e-04 - val_loss: 2.4779e-04
# Epoch 74/100
# 100/100 [==============================] - 0s 5ms/step - loss: 2.4471e-04 - val_loss: 2.4447e-04
# Epoch 75/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.4392e-04 - val_loss: 2.4316e-04
# Epoch 76/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3994e-04 - val_loss: 2.4185e-04
# Epoch 77/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.4013e-04 - val_loss: 2.4408e-04
# Epoch 78/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3967e-04 - val_loss: 2.4193e-04
# Epoch 79/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3840e-04 - val_loss: 2.3889e-04
# Epoch 80/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3727e-04 - val_loss: 2.3798e-04
# Epoch 81/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3646e-04 - val_loss: 2.3746e-04
# Epoch 82/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3557e-04 - val_loss: 2.3669e-04
# Epoch 83/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3513e-04 - val_loss: 2.3551e-04
# Epoch 84/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3524e-04 - val_loss: 2.3895e-04
# Epoch 85/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3477e-04 - val_loss: 2.3904e-04
# Epoch 86/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3440e-04 - val_loss: 2.3788e-04
# Epoch 87/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3447e-04 - val_loss: 2.3781e-04
# Epoch 88/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3337e-04 - val_loss: 2.3842e-04
# Epoch 89/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3321e-04 - val_loss: 2.3712e-04
# Epoch 90/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3297e-04 - val_loss: 2.3606e-04
# Epoch 91/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3272e-04 - val_loss: 2.3539e-04
# Epoch 92/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3204e-04 - val_loss: 2.3386e-04
# Epoch 93/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3268e-04 - val_loss: 2.3348e-04
# Epoch 94/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3185e-04 - val_loss: 2.3223e-04
# Epoch 95/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3162e-04 - val_loss: 2.3274e-04
# Epoch 96/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3140e-04 - val_loss: 2.3419e-04
# Epoch 97/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3033e-04 - val_loss: 2.3460e-04
# Epoch 98/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.3027e-04 - val_loss: 2.3120e-04
# Epoch 99/100
# 100/100 [==============================] - 0s 4ms/step - loss: 2.2961e-04 - val_loss: 2.3211e-04
# Epoch 100/100
# 100/100 [==============================] - 0s 5ms/step - loss: 2.2963e-04 - val_loss: 2.2955e-04

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# evaluate model
test_loss = autoencoder.evaluate(noisy_test, clean_test, verbose=0)

print(f'Test Loss: {test_loss}')
# Out:
# Test Loss: 0.00022568932035937905

# %%
# make predictions for test data
predictions = autoencoder.predict(noisy_test)

# select a random example from the test set
import numpy as np
i = np.random.choice(len(noisy_test))

# print the predicted and true values
#print('Predicted:', predictions[i])
#print('True:', clean_test[i])
# Out:
# 200/200 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_point_cloud(point_cloud):
    """
    Plots a 3D point cloud using matplotlib.

    Args:
    point_cloud: np.ndarray of shape (N, 3)
    """

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    xs = point_cloud[:, 0]
    ys = point_cloud[:, 1]
    zs = point_cloud[:, 2]

    ax.scatter(xs, ys, zs)

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')

    plt.show()

# %%
# %matplotlib inline

# Display a clean point cloud
plot_point_cloud(clean_test[i])

# Display its corresponding noisy point cloud
plot_point_cloud(noisy_test[i])

# Display the denoised point cloud
plot_point_cloud(predictions[i])

# %%
import json
import pandas as pd

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(history.history)

# or save to csv:
hist_csv_file = 'gdrive/My Drive/UPJV/missing/history_ae-0.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
autoencoder.save('gdrive/My Drive/UPJV/missing/ae-0.h5')

# %%
from keras.models import load_model

loaded_model = load_model('ae-0.h5')
